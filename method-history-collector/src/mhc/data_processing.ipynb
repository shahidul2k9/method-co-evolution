# %%
import numpy as np
import os
import pandas as pd
# cache_dir = os.environ.get("METHOD_CO_EVOLUTION_CACHE_DIRECTORY")
df = pd.read_csv(f"{cache_dir}/data/repository/repository.csv")

df["source"] = df["name"].map(lambda x: x.split("/")[-1])
print(df.head())
# Out:
#             name  contributor   star  \
# 0         hadoop          592  14500
# 1  elasticsearch         1932  68400
# 2          flink          908  16764
# 3    lucene-solr          234   4400
# 4         presto          734  15700
#
#                                        hash  \
# 0  4c5cd751e3911e350c7437dcb28c0ed67735f635
# 1  92be385f8ea3d39cc42155417d208ba82423d983
# 2  261e72119b69c4fc3e22d9bcdec50f6ca2fdc2e9
# 3  b457c2ee2ea0180f3a11c5d0b4d443083316aa31
# 4  bb20eba263685c6ae7b8ee71e405746eed579431
#
#                                         url
# 0          https://github.com/apache/hadoop
# 1  https://github.com/elastic/elasticsearch
# 2           https://github.com/apache/flink
# 3     https://github.com/apache/lucene-solr
# 4        https://github.com/prestodb/presto
