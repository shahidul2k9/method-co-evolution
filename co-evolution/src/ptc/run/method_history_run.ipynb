# %%
from mhc.util import run_module

# %%
run_module("ptc.generator.artifact_revision")

# %%
run_module("ptc.generator.artifact_revision_mww")

# %%
run_module("ptc.generator.t2p_revision")

# %%
run_module("ptc.generator.t2p_correlation")

# %%
run_module("ptc.generator.t2p_test_smell")
# Out:
# project=Activiti, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=265, revisions=ch_diff
# project=AntennaPod, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=24, revisions=ch_diff
# project=Essentials, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=5, revisions=ch_diff
# project=ExoPlayer, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=80, revisions=ch_diff
# project=HMCL, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=41, revisions=ch_diff
# project=Hystrix, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=5, revisions=ch_diff
# project=MPAndroidChart, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=2, revisions=ch_diff
# project=Mindustry, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=2, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=Paper, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/Paper.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=RxJava, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/RxJava.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=Signal-Server, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/Signal-Server.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=SmartTube, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/SmartTube.csv
#   warnings.warn(
# project=argouml, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=135, revisions=ch_diff
# project=async-http-client, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=41, revisions=ch_diff
# project=atmosphere, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=9, revisions=ch_diff
# project=auto, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=60, revisions=ch_diff
# project=baritone, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=1, revisions=ch_diff
# project=byte-buddy, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=323, revisions=ch_diff
# project=caffeine, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=166, revisions=ch_diff
# project=cassandra, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=547, revisions=ch_diff
# project=checkstyle, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=304, revisions=ch_diff
# project=commons-io, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=471, revisions=ch_diff
# project=commons-lang, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=848, revisions=ch_diff
# project=cucumber-jvm, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=41, revisions=ch_diff
# project=dagger, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=3, revisions=ch_diff
# project=docx4j, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=4, revisions=ch_diff
# project=dropwizard, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=37, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=dbeaver, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/dbeaver.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=eclipse.jdt.core, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/eclipse.jdt.core.csv
#   warnings.warn(
# project=dubbo, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=1419, revisions=ch_diff
# project=error-prone, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=20, revisions=ch_diff
# project=facebook-android-sdk, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=2, revisions=ch_diff
# project=fastjson, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=52, revisions=ch_diff
# project=feign, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=19, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=elasticsearch, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/elasticsearch.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=flink, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/flink.csv
#   warnings.warn(
# project=glide, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=20, revisions=ch_diff
# project=grpc-java, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=228, revisions=ch_diff
# project=gson, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=64, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=guava, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/guava.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=hadoop, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/hadoop.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=hazelcast, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/hazelcast.csv
#   warnings.warn(
# project=guice, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=50, revisions=ch_diff
# project=hbase, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=724, revisions=ch_diff
# project=hector, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=40, revisions=ch_diff
# project=hibernate-search, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=245, revisions=ch_diff
# project=hutool, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=148, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=hibernate-orm, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/hibernate-orm.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=iceberg, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/iceberg.csv
#   warnings.warn(
# project=incubator-seata, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=1518, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=intellij-community, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/intellij-community.csv
#   warnings.warn(
# project=j2objc, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=43, revisions=ch_diff
# project=javaparser, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=362, revisions=ch_diff
# project=jclouds, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=1494, revisions=ch_diff
# project=jedis, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=2951, revisions=ch_diff
# project=jenkins, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=179, revisions=ch_diff
# project=jetty.project, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=315, revisions=ch_diff
# project=jgit, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=216, revisions=ch_diff
# project=jib, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=170, revisions=ch_diff
# project=jmeter, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=107, revisions=ch_diff
# project=jna, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=488, revisions=ch_diff
# project=junit4, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=17, revisions=ch_diff
# project=junit5, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=62, revisions=ch_diff
# project=lombok, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=10, revisions=ch_diff
# project=metrics, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=4, revisions=ch_diff
# project=mockito, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=3, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=kafka, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/kafka.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=lucene, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/lucene.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=mage, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/mage.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=mybatis-plus, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/mybatis-plus.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=nacos, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/nacos.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=netty, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/netty.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=okhttp, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/okhttp.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=openmrs-core, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/openmrs-core.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=pentaho-kettle, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/pentaho-kettle.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=plantuml, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/plantuml.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=pmd, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/pmd.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=presto, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/presto.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=pulsar, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/pulsar.csv
#   warnings.warn(
# project=mongo-java-driver, tool=historyFinder, strategy=nc, smell_detector=jnose: rows=468, revisions=ch_diff
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=redisson, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/redisson.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=rocketmq, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/rocketmq.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=seatunnel, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/seatunnel.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=shardingsphere-elasticjob, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/shardingsphere-elasticjob.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=shardingsphere, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/shardingsphere.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=shenyu, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/shenyu.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=skywalking, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/skywalking.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=solr, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/solr.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=sonarqube, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/sonarqube.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=spring-boot, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/spring-boot.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=spring-cloud-alibaba, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/spring-cloud-alibaba.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=spring-framework, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/spring-framework.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=titan, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/titan.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=tomcat, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/tomcat.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=vert.x, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/vert.x.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=visualvm, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/visualvm.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=voldemort, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/voldemort.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=vraptor4, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/vraptor4.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=weka, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/weka.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=wicket, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/wicket.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=wildfly, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/wildfly.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=wiremock, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/wiremock.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=xerces2-j, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/xerces2-j.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=xpipe, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/xpipe.csv
#   warnings.warn(
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_test_smell.py:181: UserWarning: Skipping project=zxing, tool=historyFinder, strategy=nc, smell_detector=jnose: Test smell CSV not found: /Users/shahidul/dev/project/method-co-evolution/workspace/experiment/main/test-smell/jnose/zxing.csv
#   warnings.warn(
