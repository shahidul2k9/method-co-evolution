# %%
from mhc.util import run_module

# %%
run_module("ptc.generator.generate_change")
# Out:
# generate_change summary [historyFinder]: processed=6, skipped=0, empty_history=0, invalid_history=2

# %%
run_module("ptc.generator.generate_t2p_mwu")

# %%
run_module("ptc.generator.generate_t2p_delta")
