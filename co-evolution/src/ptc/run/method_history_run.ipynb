# %% [markdown]
# Data analysis the with method revisions.

# %%
from mhc.util import run_module

# %%
run_module("ptc.generator.artifact_revision")

# %%
run_module("ptc.generator.artifact_revision_mww")

# %%
run_module("ptc.generator.t2p_revision")

# %%
run_module("ptc.generator.t2p_correlation", args=["--replace"])

# %% [markdown]
# Test Smells

# %%
run_module("ptc.generator.t2p_test_smell_revision", args=["--replace"])

# %%
# run_module("ptc.generator.t2p_test_smell_loc_group", args=["--replace"])

# %%
run_module("ptc.generator.t2p_test_smell_prevalence", args=["--replace"])

# %%
run_module("ptc.generator.t2p_test_smell_count_mww", args=["--replace"])

# %%
run_module("ptc.generator.t2p_test_smell_prevalence_wilcoxon_srt", args=["--replace"])

# %%
run_module("ptc.generator.t2p_test_smell_association", args=["--replace", "--revision-group-pairs", "HTR,NTR;ATR,NTR;AHTR,NTR"])

# %%
run_module("ptc.generator.t2p_test_smell_size_control_association", args=["--replace", "--revision-group-pairs", "HTR,NTR;ATR,NTR;AHTR,NTR"])
