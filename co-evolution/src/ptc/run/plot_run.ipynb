# %%
from mhc.util import run_module

# %%
# run_module("ptc.plot.fan_cdf")

# %%
run_module("ptc.plot.change_cdf")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/plot/change_cdf.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   history_repository_dfs = [pd.read_csv(repository_history_file, keep_default_na=False, na_filter=False) for
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/plot/change_cdf.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   history_repository_dfs = [pd.read_csv(repository_history_file, keep_default_na=False, na_filter=False) for
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/plot/change_cdf.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   history_repository_dfs = [pd.read_csv(repository_history_file, keep_default_na=False, na_filter=False) for
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/plot/change_cdf.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   history_repository_dfs = [pd.read_csv(repository_history_file, keep_default_na=False, na_filter=False) for

# %%
run_module("ptc.plot.pt_change_scatter")
# Out:
# codeShovel lc
# codeShovel lcba
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel max
# codeShovel nc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel ncc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel omc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel omc--nc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel omc--nc--ncc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# codeShovel omc--nc--ncc--lcba
# codeShovel omc--nc--ncc--max
# historyFinder lc
# historyFinder lcba
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder max
# historyFinder nc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder ncc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder omc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder omc--nc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder omc--nc--ncc
# /Users/shahidul/dev/project/method-co-evolution/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1625: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return kendalltau(a, b)[0]
# historyFinder omc--nc--ncc--lcba
# historyFinder omc--nc--ncc--max

# %%
run_module("ptc.plot.pt_change_stats_cdf")
