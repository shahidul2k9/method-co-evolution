# %%
from pathlib import Path
from dotenv import load_dotenv

from mhc.util import find_root, run_module

load_dotenv(dotenv_path=f"{find_root(Path.cwd())}/.env", override=True)

# %%
run_module("ptc.generator.artifact_callgraph")

# %%
run_module("ptc.generator.expand_t2p_candidate")

# %%
run_module("ptc.generator.method_call_statistics")

# %%
run_module("ptc.generator.t2p_technique")

# %%
run_module("ptc.generator.t2p_link")
