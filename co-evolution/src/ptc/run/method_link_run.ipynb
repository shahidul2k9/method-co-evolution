# %%
from pathlib import Path

from dotenv import load_dotenv
from mhc.util import find_root, run_module

load_dotenv(dotenv_path=f"{find_root(Path.cwd())}/.env", override=True)

from mhc.config import DATA_DIRECTORY,WORKSPACE_DIRECTORY

IS_WHITE_EXPERIMENT = "workspace-eval" in Path(WORKSPACE_DIRECTORY).resolve().parts

# %%
run_module("ptc.generator.generate_callgraph_degree")

# %%
run_module("ptc.generator.expand_t2p_candidate")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.filter_t2p_candidate")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: gson
# Processing: jfreechart
# Processing: dubbo
# Processing: jenkins
# Finished.

# %%
if IS_WHITE_EXPERIMENT:
    print("Generating t2p candidates")
    run_module("ptc.generator.filter_t2p_candidate_ground_truth")
# Out:
# Generating t2p candidates
# +--------------+-------------+------------+-----------+-----------+-------+
# | project      | rows_before | rows_after | test_urls | prod_urls | links |
# +--------------+-------------+------------+-----------+-----------+-------+
# |   commons-io |       13276 |        210 |        28 |        86 |   136 |
# | commons-lang |       36268 |        522 |        42 |       131 |   143 |
# |         gson |       11819 |        302 |        50 |        89 |   176 |
# |   jfreechart |       49600 |        231 |        28 |       122 |   133 |
# |        dubbo |      108871 |        500 |        41 |       164 |   342 |
# |      jenkins |       67689 |        423 |        42 |       163 |   225 |
# +--------------+-------------+------------+-----------+-----------+-------+
# |        total |      287523 |       2188 |       231 |       755 |  1155 |
# +--------------+-------------+------------+-----------+-----------+-------+
# Finished.

# %%
run_module("ptc.generator.generate_t2p_tech")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# commons-io omc 4
# commons-io nc 1
# commons-io ncc 16
# commons-io lc 21
# commons-io lcba 46
# commons-io max 93
# commons-io lcs-u 36
# commons-io lcs-b 36
# commons-io leven 18
# commons-io tarantula 41
# commons-io tfidf 37
# commons-io combined 34
# commons-io omc--nc 5
# commons-io omc--nc--ncc 17
# commons-io omc--nc--ncc--lcba 50
# commons-io omc--nc--ncc--max 93
# commons-io omc--nc--ncc--lcs-u 38
# commons-io omc--nc--ncc--lcs-b 38
# commons-io omc--nc--ncc--leven 27
# commons-io omc--nc--ncc--combined 36
# commons-io gpt-oss-20b 29
# commons-io gpt-oss-120b 31
# commons-io qwen-2d5b 0
# commons-io testlinker 26
# commons-lang omc 8
# commons-lang nc 9
# commons-lang ncc 42
# commons-lang lc 41
# commons-lang lcba 86
# commons-lang max 121
# commons-lang lcs-u 66
# commons-lang lcs-b 76
# commons-lang leven 46
# commons-lang tarantula 110
# commons-lang tfidf 96
# commons-lang combined 60
# commons-lang omc--nc 16
# commons-lang omc--nc--ncc 44
# commons-lang omc--nc--ncc--lcba 93
# commons-lang omc--nc--ncc--max 121
# commons-lang omc--nc--ncc--lcs-u 67
# commons-lang omc--nc--ncc--lcs-b 76
# commons-lang omc--nc--ncc--leven 56
# commons-lang omc--nc--ncc--combined 60
# commons-lang gpt-oss-20b 83
# commons-lang gpt-oss-120b 69
# commons-lang qwen-2d5b 0
# commons-lang testlinker 55
# gson omc 20
# gson nc 6
# gson ncc 17
# gson lc 21
# gson lcba 84
# gson max 109
# gson lcs-u 59
# gson lcs-b 59
# gson leven 26
# gson tarantula 88
# gson tfidf 73
# gson combined 59
# gson omc--nc 24
# gson omc--nc--ncc 35
# gson omc--nc--ncc--lcba 87
# gson omc--nc--ncc--max 109
# gson omc--nc--ncc--lcs-u 62
# gson omc--nc--ncc--lcs-b 64
# gson omc--nc--ncc--leven 45
# gson omc--nc--ncc--combined 63
# gson gpt-oss-20b 68
# gson gpt-oss-120b 66
# gson qwen-2d5b 0
# gson testlinker 50
# jfreechart omc 1
# jfreechart nc 7
# jfreechart ncc 11
# jfreechart lc 28
# jfreechart lcba 67
# jfreechart max 91
# jfreechart lcs-u 30
# jfreechart lcs-b 39
# jfreechart leven 26
# jfreechart tarantula 91
# jfreechart tfidf 85
# jfreechart combined 35
# jfreechart omc--nc 8
# jfreechart omc--nc--ncc 12
# jfreechart omc--nc--ncc--lcba 68
# jfreechart omc--nc--ncc--max 91
# jfreechart omc--nc--ncc--lcs-u 30
# jfreechart omc--nc--ncc--lcs-b 39
# jfreechart omc--nc--ncc--leven 26
# jfreechart omc--nc--ncc--combined 35
# jfreechart gpt-oss-20b 36
# jfreechart gpt-oss-120b 32
# jfreechart qwen-2d5b 0
# jfreechart testlinker 28
# dubbo omc 4
# dubbo nc 17
# dubbo ncc 37
# dubbo lc 40
# dubbo lcba 98
# dubbo max 281
# dubbo lcs-u 74
# dubbo lcs-b 110
# dubbo leven 48
# dubbo tarantula 138
# dubbo tfidf 103
# dubbo combined 59
# dubbo omc--nc 17
# dubbo omc--nc--ncc 37
# dubbo omc--nc--ncc--lcba 114
# dubbo omc--nc--ncc--max 281
# dubbo omc--nc--ncc--lcs-u 74
# dubbo omc--nc--ncc--lcs-b 113
# dubbo omc--nc--ncc--leven 59
# dubbo omc--nc--ncc--combined 63
# dubbo gpt-oss-20b 82
# dubbo gpt-oss-120b 77
# dubbo qwen-2d5b 0
# dubbo testlinker 52
# jenkins omc 2
# jenkins nc 11
# jenkins ncc 23
# jenkins lc 39
# jenkins lcba 87
# jenkins max 163
# jenkins lcs-u 54
# jenkins lcs-b 66
# jenkins leven 41
# jenkins tarantula 90
# jenkins tfidf 74
# jenkins combined 42
# jenkins omc--nc 12
# jenkins omc--nc--ncc 24
# jenkins omc--nc--ncc--lcba 92
# jenkins omc--nc--ncc--max 163
# jenkins omc--nc--ncc--lcs-u 54
# jenkins omc--nc--ncc--lcs-b 70
# jenkins omc--nc--ncc--leven 45
# jenkins omc--nc--ncc--combined 46
# jenkins gpt-oss-20b 0
# jenkins gpt-oss-120b 45
# jenkins qwen-2d5b 0
# jenkins testlinker 32

# %%
if IS_WHITE_EXPERIMENT:
    run_module("ptc.generator.t2p_link_evaluation")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_link_evaluation.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(items, ignore_index=True)

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.generate_t2p_mwu")

# %%
run_module("ptc.generator.generate_t2p_delta")
