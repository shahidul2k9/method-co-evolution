# %%
from pathlib import Path

from dotenv import load_dotenv
from mhc.util import find_root, run_module

load_dotenv(dotenv_path=f"{find_root(Path.cwd())}/.env", override=True)

from mhc.config import DATA_DIRECTORY

IS_WHITE_EXPERIMENT = ".white" in Path(DATA_DIRECTORY).resolve().parts

# %%
run_module("ptc.generator.generate_fan")

# %%
run_module("ptc.generator.generate_m2m_candidate")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
if IS_WHITE_EXPERIMENT:
    run_module("ptc.generator.filter_m2m_candidate_ground_truth")
# Out:
# Filtered commons-io: 6803 -> 92 rows
# Filtered commons-lang: 25598 -> 392 rows
# Filtered dubbo: 60448 -> 313 rows
# Filtered gson: 7402 -> 203 rows
# Filtered jenkins: 23800 -> 223 rows
# Filtered jfreechart: 25426 -> 169 rows
# Finished.

# %%
run_module("ptc.generator.generate_m2m_tech")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# commons-io omc 8
# commons-io nc 1
# commons-io ncc 13
# commons-io lc 21
# commons-io lcba 31
# commons-io max 56
# commons-io lcs-u 36
# commons-io lcs-b 36
# commons-io leven 23
# commons-io tarantula 42
# commons-io tfidf 42
# commons-io combined 33
# commons-io omc--nc 8
# commons-io omc--nc--ncc 17
# commons-io omc--nc--ncc--lcba 37
# commons-io omc--nc--ncc--max 56
# commons-io omc--nc--ncc--lcs-u 36
# commons-io omc--nc--ncc--lcs-b 36
# commons-io omc--nc--ncc--leven 28
# commons-io omc--nc--ncc--combined 33
# commons-io gpt-oss-20b 30
# commons-io gpt-oss-120b 32
# commons-io qwen-2d5b 0
# commons-lang omc 9
# commons-lang nc 9
# commons-lang ncc 39
# commons-lang lc 41
# commons-lang lcba 71
# commons-lang max 93
# commons-lang lcs-u 64
# commons-lang lcs-b 70
# commons-lang leven 46
# commons-lang tarantula 93
# commons-lang tfidf 90
# commons-lang combined 58
# commons-lang omc--nc 16
# commons-lang omc--nc--ncc 41
# commons-lang omc--nc--ncc--lcba 77
# commons-lang omc--nc--ncc--max 93
# commons-lang omc--nc--ncc--lcs-u 64
# commons-lang omc--nc--ncc--lcs-b 70
# commons-lang omc--nc--ncc--leven 54
# commons-lang omc--nc--ncc--combined 58
# commons-lang gpt-oss-20b 84
# commons-lang gpt-oss-120b 69
# commons-lang qwen-2d5b 0
# gson omc 24
# gson nc 6
# gson ncc 14
# gson lc 50
# gson lcba 78
# gson max 99
# gson lcs-u 59
# gson lcs-b 67
# gson leven 50
# gson tarantula 89
# gson tfidf 80
# gson combined 61
# gson omc--nc 28
# gson omc--nc--ncc 36
# gson omc--nc--ncc--lcba 81
# gson omc--nc--ncc--max 99
# gson omc--nc--ncc--lcs-u 59
# gson omc--nc--ncc--lcs-b 68
# gson omc--nc--ncc--leven 52
# gson omc--nc--ncc--combined 62
# gson gpt-oss-20b 69
# gson gpt-oss-120b 67
# gson qwen-2d5b 0
# jfreechart omc 5
# jfreechart nc 3
# jfreechart ncc 5
# jfreechart lc 26
# jfreechart lcba 57
# jfreechart max 70
# jfreechart lcs-u 28
# jfreechart lcs-b 38
# jfreechart leven 23
# jfreechart tarantula 70
# jfreechart tfidf 64
# jfreechart combined 37
# jfreechart omc--nc 8
# jfreechart omc--nc--ncc 10
# jfreechart omc--nc--ncc--lcba 58
# jfreechart omc--nc--ncc--max 70
# jfreechart omc--nc--ncc--lcs-u 28
# jfreechart omc--nc--ncc--lcs-b 39
# jfreechart omc--nc--ncc--leven 24
# jfreechart omc--nc--ncc--combined 38
# jfreechart gpt-oss-20b 42
# jfreechart gpt-oss-120b 37
# jfreechart qwen-2d5b 0
# dubbo omc 8
# dubbo nc 17
# dubbo ncc 33
# dubbo lc 41
# dubbo lcba 84
# dubbo max 193
# dubbo lcs-u 64
# dubbo lcs-b 96
# dubbo leven 47
# dubbo tarantula 127
# dubbo tfidf 98
# dubbo combined 59
# dubbo omc--nc 20
# dubbo omc--nc--ncc 36
# dubbo omc--nc--ncc--lcba 97
# dubbo omc--nc--ncc--max 193
# dubbo omc--nc--ncc--lcs-u 64
# dubbo omc--nc--ncc--lcs-b 99
# dubbo omc--nc--ncc--leven 55
# dubbo omc--nc--ncc--combined 61
# dubbo gpt-oss-20b 83
# dubbo gpt-oss-120b 78
# dubbo qwen-2d5b 0
# jenkins omc 5
# jenkins nc 10
# jenkins ncc 19
# jenkins lc 32
# jenkins lcba 48
# jenkins max 82
# jenkins lcs-u 48
# jenkins lcs-b 53
# jenkins leven 37
# jenkins tarantula 68
# jenkins tfidf 62
# jenkins combined 44
# jenkins omc--nc 14
# jenkins omc--nc--ncc 22
# jenkins omc--nc--ncc--lcba 52
# jenkins omc--nc--ncc--max 82
# jenkins omc--nc--ncc--lcs-u 48
# jenkins omc--nc--ncc--lcs-b 55
# jenkins omc--nc--ncc--leven 40
# jenkins omc--nc--ncc--combined 46
# jenkins gpt-oss-20b 0
# jenkins gpt-oss-120b 46
# jenkins qwen-2d5b 0

# %%
if IS_WHITE_EXPERIMENT:
    run_module("ptc.generator.t2p_link_evaluation")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_link_evaluation.py:128: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(items, ignore_index=True)

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.generate_t2p_mwu")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 run_module("ptc.generator.generate_t2p_mwu")
#
# File ~/dev/project/method-co-evolution/method-history-collector/src/mhc/util.py:137, in run_module(module_name, project_root, args)
#     134 if args:
#     135     command.extend(args)
# --> 137 subprocess.run(
#     138     command,
#     139     check=True,
#     140     cwd=project_root,
#     141 )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
run_module("ptc.generator.generate_t2p_delta")
