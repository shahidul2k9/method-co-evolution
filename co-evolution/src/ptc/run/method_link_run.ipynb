# %%
from pathlib import Path

from dotenv import load_dotenv
from mhc.util import find_root, run_module

load_dotenv(dotenv_path=f"{find_root(Path.cwd())}/.env", override=True)

from mhc.config import DATA_DIRECTORY

IS_WHITE_EXPERIMENT = ".white" in Path(DATA_DIRECTORY).resolve().parts

# %%
run_module("ptc.generator.generate_callgraph_degree")

# %%
run_module("ptc.generator.generate_m2m_candidate")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
if IS_WHITE_EXPERIMENT:
    run_module("ptc.generator.filter_m2m_candidate_ground_truth")
# Out:
# +--------------+-------------+------------+-----------+-----------+-------+
# | project      | rows_before | rows_after | test_urls | prod_urls | links |
# +--------------+-------------+------------+-----------+-----------+-------+
# |   commons-io |       11149 |        157 |        27 |        68 |   106 |
# | commons-lang |       33945 |        506 |        42 |       121 |   133 |
# |         gson |        9596 |        225 |        50 |        80 |   135 |
# |   jfreechart |       49600 |        231 |        28 |       122 |   133 |
# |        dubbo |      103159 |        469 |        41 |       144 |   315 |
# |      jenkins |       63713 |        381 |        42 |       140 |   195 |
# +--------------+-------------+------------+-----------+-----------+-------+
# |        total |      271162 |       1969 |       230 |       675 |  1017 |
# +--------------+-------------+------------+-----------+-----------+-------+
# Finished.

# %%
run_module("ptc.generator.generate_m2m_tech")
# Out:
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# commons-io omc 4
# commons-io nc 1
# commons-io ncc 16
# commons-io lc 22
# commons-io lcba 46
# commons-io max 93
# commons-io lcs-u 46
# commons-io lcs-b 50
# commons-io leven 25
# commons-io tarantula 55
# commons-io tfidf 52
# commons-io combined 41
# commons-io omc--nc 5
# commons-io omc--nc--ncc 17
# commons-io omc--nc--ncc--lcba 50
# commons-io omc--nc--ncc--max 93
# commons-io omc--nc--ncc--lcs-u 46
# commons-io omc--nc--ncc--lcs-b 50
# commons-io omc--nc--ncc--leven 32
# commons-io omc--nc--ncc--combined 41
# commons-io gpt-oss-20b 29
# commons-io gpt-oss-120b 31
# commons-io qwen-2d5b 0
# commons-io testlinker 26
# commons-lang omc 8
# commons-lang nc 9
# commons-lang ncc 41
# commons-lang lc 42
# commons-lang lcba 85
# commons-lang max 119
# commons-lang lcs-u 68
# commons-lang lcs-b 75
# commons-lang leven 48
# commons-lang tarantula 115
# commons-lang tfidf 99
# commons-lang combined 61
# commons-lang omc--nc 16
# commons-lang omc--nc--ncc 43
# commons-lang omc--nc--ncc--lcba 92
# commons-lang omc--nc--ncc--max 119
# commons-lang omc--nc--ncc--lcs-u 68
# commons-lang omc--nc--ncc--lcs-b 75
# commons-lang omc--nc--ncc--leven 57
# commons-lang omc--nc--ncc--combined 61
# commons-lang gpt-oss-20b 82
# commons-lang gpt-oss-120b 68
# commons-lang qwen-2d5b 0
# commons-lang testlinker 54
# gson omc 20
# gson nc 6
# gson ncc 17
# gson lc 50
# gson lcba 84
# gson max 109
# gson lcs-u 63
# gson lcs-b 71
# gson leven 50
# gson tarantula 91
# gson tfidf 76
# gson combined 64
# gson omc--nc 24
# gson omc--nc--ncc 35
# gson omc--nc--ncc--lcba 87
# gson omc--nc--ncc--max 109
# gson omc--nc--ncc--lcs-u 63
# gson omc--nc--ncc--lcs-b 72
# gson omc--nc--ncc--leven 53
# gson omc--nc--ncc--combined 65
# gson gpt-oss-20b 68
# gson gpt-oss-120b 66
# gson qwen-2d5b 0
# gson testlinker 50
# jfreechart omc 1
# jfreechart nc 7
# jfreechart ncc 11
# jfreechart lc 28
# jfreechart lcba 67
# jfreechart max 91
# jfreechart lcs-u 30
# jfreechart lcs-b 39
# jfreechart leven 26
# jfreechart tarantula 91
# jfreechart tfidf 85
# jfreechart combined 35
# jfreechart omc--nc 8
# jfreechart omc--nc--ncc 12
# jfreechart omc--nc--ncc--lcba 68
# jfreechart omc--nc--ncc--max 91
# jfreechart omc--nc--ncc--lcs-u 30
# jfreechart omc--nc--ncc--lcs-b 39
# jfreechart omc--nc--ncc--leven 26
# jfreechart omc--nc--ncc--combined 35
# jfreechart gpt-oss-20b 36
# jfreechart gpt-oss-120b 32
# jfreechart qwen-2d5b 0
# jfreechart testlinker 28
# dubbo omc 4
# dubbo nc 17
# dubbo ncc 37
# dubbo lc 41
# dubbo lcba 98
# dubbo max 281
# dubbo lcs-u 74
# dubbo lcs-b 113
# dubbo leven 49
# dubbo tarantula 140
# dubbo tfidf 107
# dubbo combined 59
# dubbo omc--nc 17
# dubbo omc--nc--ncc 37
# dubbo omc--nc--ncc--lcba 114
# dubbo omc--nc--ncc--max 281
# dubbo omc--nc--ncc--lcs-u 74
# dubbo omc--nc--ncc--lcs-b 116
# dubbo omc--nc--ncc--leven 60
# dubbo omc--nc--ncc--combined 63
# dubbo gpt-oss-20b 82
# dubbo gpt-oss-120b 77
# dubbo qwen-2d5b 0
# dubbo testlinker 52
# jenkins omc 2
# jenkins nc 11
# jenkins ncc 23
# jenkins lc 39
# jenkins lcba 87
# jenkins max 163
# jenkins lcs-u 66
# jenkins lcs-b 80
# jenkins leven 50
# jenkins tarantula 110
# jenkins tfidf 89
# jenkins combined 58
# jenkins omc--nc 12
# jenkins omc--nc--ncc 24
# jenkins omc--nc--ncc--lcba 92
# jenkins omc--nc--ncc--max 163
# jenkins omc--nc--ncc--lcs-u 66
# jenkins omc--nc--ncc--lcs-b 84
# jenkins omc--nc--ncc--leven 54
# jenkins omc--nc--ncc--combined 62
# jenkins gpt-oss-20b 0
# jenkins gpt-oss-120b 45
# jenkins qwen-2d5b 0
# jenkins testlinker 32

# %%
if IS_WHITE_EXPERIMENT:
    run_module("ptc.generator.t2p_link_evaluation")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_link_evaluation.py:132: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(items, ignore_index=True)

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.generate_t2p_mwu")

# %%
run_module("ptc.generator.generate_t2p_delta")
