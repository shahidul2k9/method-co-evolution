# %%
from mhc.util import run_module

# %%
run_module("ptc.generator.generate_fan")

# %%
run_module("ptc.generator.generate_m2m_candidate")
# Out:
# Processing: Activiti
# Processing: ant
# Processing: AntennaPod
# Processing: Apktool
# Processing: argouml
# Processing: async-http-client
# Processing: atmosphere
# Processing: auto
# Processing: baritone
# Processing: byte-buddy
# Processing: caffeine
# Processing: commons-io
# Processing: commons-lang
# Processing: cucumber-jvm
# Processing: dagger
# Processing: dbeaver
# Processing: docx4j
# Processing: dropwizard
# Processing: dubbo
# Processing: error-prone
# Processing: Essentials
# Processing: ExoPlayer
# Processing: facebook-android-sdk
# Processing: fastjson
# Processing: feign
# Processing: flyway
# Processing: glide
# Processing: grpc-java
# Processing: gson
# Processing: guava
# Processing: guice
# Processing: hector
# Processing: hibernate-search
# Processing: HMCL
# Processing: hutool
# Processing: Hystrix
# Processing: incubator-seata
# Processing: j2objc
# Processing: javaparser
# Processing: jedis
# Processing: jenkins
# Processing: jgit
# Processing: jib
# Processing: jmeter
# Processing: jna
# Processing: junit4
# Processing: junit5
# Processing: metrics
# Processing: MinecraftForge
# Processing: mockito
# Processing: mongo-java-driver
# Processing: MPAndroidChart
# Processing: mybatis-plus
# Processing: nacos
# Processing: netty
# Processing: okhttp
# Processing: openmrs-core
# Processing: Paper
# Processing: plantuml
# Processing: pmd
# Processing: redisson
# Processing: rocketmq
# Processing: seatunnel
# Processing: shardingsphere
# Processing: shardingsphere-elasticjob
# Processing: shenyu
# Processing: Signal-Server
# Processing: skywalking
# Processing: SmartTube
# Processing: solr
# Processing: sonarqube
# Processing: spring-boot
# Processing: spring-cloud-alibaba
# Processing: spring-framework
# Processing: titan
# Processing: tomcat
# Processing: vert.x
# Processing: visualvm
# Processing: voldemort
# Processing: vraptor4
# Processing: wiremock
# Processing: xerces2-j
# Processing: xpipe
# Processing: zxing
# Finished.

# %%
run_module("ptc.generator.generate_m2m_tech")
# Out:
# Processing: Activiti
# Processing: ant
# Processing: AntennaPod
# Processing: Apktool
# Processing: argouml
# Processing: async-http-client
# Processing: atmosphere
# Processing: auto
# Processing: baritone
# Processing: byte-buddy
# Processing: caffeine
# Processing: commons-io
# Processing: commons-lang
# Processing: cucumber-jvm
# Processing: dagger
# Processing: dbeaver
# Processing: docx4j
# Processing: dropwizard
# Processing: dubbo
# Processing: error-prone
# Processing: Essentials
# Processing: ExoPlayer
# Processing: facebook-android-sdk
# Processing: fastjson
# Processing: feign
# Processing: flyway
# Processing: glide
# Processing: grpc-java
# Processing: gson
# Processing: guava
# Processing: guice
# Processing: hector
# Processing: hibernate-search
# Processing: HMCL
# Processing: hutool
# Processing: Hystrix
# Processing: incubator-seata
# Processing: j2objc
# Processing: javaparser
# Processing: jedis
# Processing: jenkins
# Processing: jgit
# Processing: jib
# Processing: jmeter
# Processing: jna
# Processing: junit4
# Processing: junit5
# Processing: metrics
# Processing: MinecraftForge
# Processing: mockito
# Processing: mongo-java-driver
# Processing: MPAndroidChart
# Processing: mybatis-plus
# Processing: nacos
# Processing: netty
# Processing: okhttp
# Processing: openmrs-core
# Processing: Paper
# Processing: plantuml
# Processing: pmd
# Processing: redisson
# Processing: rocketmq
# Processing: seatunnel
# Processing: shardingsphere
# Processing: shardingsphere-elasticjob
# Processing: shenyu
# Processing: Signal-Server
# Processing: skywalking
# Processing: SmartTube
# Processing: solr
# Processing: sonarqube
# Processing: spring-boot
# Processing: spring-cloud-alibaba
# Processing: spring-framework
# Processing: titan
# Processing: tomcat
# Processing: vert.x
# Processing: visualvm
# Processing: voldemort
# Processing: vraptor4
# Processing: wiremock
# Processing: xerces2-j
# Processing: xpipe
# Processing: zxing
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# xerces2-j omc 55
# xerces2-j nc 0
# xerces2-j ncc 0
# xerces2-j lc 104
# xerces2-j lcba 168
# xerces2-j max 338
# xerces2-j omc--nc 55
# xerces2-j omc--nc--ncc 55
# xerces2-j omc--nc--ncc--lcba 199
# xerces2-j omc--nc--ncc--max 338
# xerces2-j gpt-oss-20b 0
# xerces2-j gpt-oss-120b 0
# xerces2-j qwen-2d5b 0
# guava omc 3177
# guava nc 2327
# guava ncc 13425
# guava lc 15387
# guava lcba 23600
# guava max 51931
# guava omc--nc 5108
# guava omc--nc--ncc 14579
# guava omc--nc--ncc--lcba 29612
# guava omc--nc--ncc--max 51949
# guava gpt-oss-20b 0
# guava gpt-oss-120b 0
# guava qwen-2d5b 0
# jenkins omc 584
# jenkins nc 121
# jenkins ncc 526
# jenkins lc 1797
# jenkins lcba 2401
# jenkins max 4520
# jenkins omc--nc 680
# jenkins omc--nc--ncc 977
# jenkins omc--nc--ncc--lcba 2743
# jenkins omc--nc--ncc--max 4521
# jenkins gpt-oss-20b 0
# jenkins gpt-oss-120b 0
# jenkins qwen-2d5b 0
# glide omc 451
# glide nc 10
# glide ncc 915
# glide lc 1314
# glide lcba 1102
# glide max 3101
# glide omc--nc 458
# glide omc--nc--ncc 1176
# glide omc--nc--ncc--lcba 1679
# glide omc--nc--ncc--max 3104
# glide gpt-oss-20b 0
# glide gpt-oss-120b 0
# glide qwen-2d5b 0
# titan omc 55
# titan nc 11
# titan ncc 101
# titan lc 416
# titan lcba 681
# titan max 2419
# titan omc--nc 59
# titan omc--nc--ncc 145
# titan omc--nc--ncc--lcba 784
# titan omc--nc--ncc--max 2428
# titan gpt-oss-20b 0
# titan gpt-oss-120b 0
# titan qwen-2d5b 0
# openmrs-core omc 1066
# openmrs-core nc 4
# openmrs-core ncc 3544
# openmrs-core lc 4497
# openmrs-core lcba 7483
# openmrs-core max 20683
# openmrs-core omc--nc 1066
# openmrs-core omc--nc--ncc 3873
# openmrs-core omc--nc--ncc--lcba 8657
# openmrs-core omc--nc--ncc--max 20683
# openmrs-core gpt-oss-20b 0
# openmrs-core gpt-oss-120b 0
# openmrs-core qwen-2d5b 0
# flyway omc 3
# flyway nc 0
# flyway ncc 0
# flyway lc 9
# flyway lcba 0
# flyway max 19
# flyway omc--nc 3
# flyway omc--nc--ncc 3
# flyway omc--nc--ncc--lcba 3
# flyway omc--nc--ncc--max 19
# flyway gpt-oss-20b 0
# flyway gpt-oss-120b 0
# flyway qwen-2d5b 0
# shardingsphere-elasticjob omc 289
# shardingsphere-elasticjob nc 3
# shardingsphere-elasticjob ncc 400
# shardingsphere-elasticjob lc 591
# shardingsphere-elasticjob lcba 449
# shardingsphere-elasticjob max 1652
# shardingsphere-elasticjob omc--nc 289
# shardingsphere-elasticjob omc--nc--ncc 511
# shardingsphere-elasticjob omc--nc--ncc--lcba 710
# shardingsphere-elasticjob omc--nc--ncc--max 1652
# shardingsphere-elasticjob gpt-oss-20b 0
# shardingsphere-elasticjob gpt-oss-120b 0
# shardingsphere-elasticjob qwen-2d5b 0
# javaparser omc 511
# javaparser nc 360
# javaparser ncc 1799
# javaparser lc 4095
# javaparser lcba 8397
# javaparser max 21785
# javaparser omc--nc 826
# javaparser omc--nc--ncc 2139
# javaparser omc--nc--ncc--lcba 9099
# javaparser omc--nc--ncc--max 21788
# javaparser gpt-oss-20b 0
# javaparser gpt-oss-120b 0
# javaparser qwen-2d5b 0
# xpipe omc 7
# xpipe nc 0
# xpipe ncc 4
# xpipe lc 14
# xpipe lcba 1
# xpipe max 24
# xpipe omc--nc 7
# xpipe omc--nc--ncc 9
# xpipe omc--nc--ncc--lcba 9
# xpipe omc--nc--ncc--max 25
# xpipe gpt-oss-20b 0
# xpipe gpt-oss-120b 0
# xpipe qwen-2d5b 0
# MinecraftForge omc 5
# MinecraftForge nc 6
# MinecraftForge ncc 37
# MinecraftForge lc 51
# MinecraftForge lcba 121
# MinecraftForge max 164
# MinecraftForge omc--nc 11
# MinecraftForge omc--nc--ncc 42
# MinecraftForge omc--nc--ncc--lcba 135
# MinecraftForge omc--nc--ncc--max 164
# MinecraftForge gpt-oss-20b 0
# MinecraftForge gpt-oss-120b 0
# MinecraftForge qwen-2d5b 0
# fastjson omc 2300
# fastjson nc 48
# fastjson ncc 159
# fastjson lc 5002
# fastjson lcba 5756
# fastjson max 8057
# fastjson omc--nc 2332
# fastjson omc--nc--ncc 2401
# fastjson omc--nc--ncc--lcba 6255
# fastjson omc--nc--ncc--max 8189
# fastjson gpt-oss-20b 0
# fastjson gpt-oss-120b 0
# fastjson qwen-2d5b 0
# vraptor4 omc 298
# vraptor4 nc 0
# vraptor4 ncc 347
# vraptor4 lc 805
# vraptor4 lcba 546
# vraptor4 max 1653
# vraptor4 omc--nc 298
# vraptor4 omc--nc--ncc 539
# vraptor4 omc--nc--ncc--lcba 835
# vraptor4 omc--nc--ncc--max 1653
# vraptor4 gpt-oss-20b 0
# vraptor4 gpt-oss-120b 0
# vraptor4 qwen-2d5b 0
# solr omc 934
# solr nc 217
# solr ncc 724
# solr lc 4680
# solr lcba 7923
# solr max 20550
# solr omc--nc 1103
# solr omc--nc--ncc 1525
# solr omc--nc--ncc--lcba 8478
# solr omc--nc--ncc--max 20556
# solr gpt-oss-20b 0
# solr gpt-oss-120b 0
# solr qwen-2d5b 0
# jna omc 273
# jna nc 505
# jna ncc 732
# jna lc 1281
# jna lcba 2614
# jna max 4789
# jna omc--nc 683
# jna omc--nc--ncc 868
# jna omc--nc--ncc--lcba 2828
# jna omc--nc--ncc--max 4789
# jna gpt-oss-20b 0
# jna gpt-oss-120b 0
# jna qwen-2d5b 0
# nacos omc 1512
# nacos nc 1941
# nacos ncc 4101
# nacos lc 5617
# nacos lcba 10424
# nacos max 23762
# nacos omc--nc 2863
# nacos omc--nc--ncc 4454
# nacos omc--nc--ncc--lcba 11873
# nacos omc--nc--ncc--max 23762
# nacos gpt-oss-20b 0
# nacos gpt-oss-120b 0
# nacos qwen-2d5b 0
# hutool omc 847
# hutool nc 145
# hutool ncc 2238
# hutool lc 3208
# hutool lcba 3949
# hutool max 8576
# hutool omc--nc 949
# hutool omc--nc--ncc 2512
# hutool omc--nc--ncc--lcba 4598
# hutool omc--nc--ncc--max 8582
# hutool gpt-oss-20b 0
# hutool gpt-oss-120b 0
# hutool qwen-2d5b 0
# dropwizard omc 466
# dropwizard nc 8
# dropwizard ncc 157
# dropwizard lc 812
# dropwizard lcba 1071
# dropwizard max 1711
# dropwizard omc--nc 470
# dropwizard omc--nc--ncc 575
# dropwizard omc--nc--ncc--lcba 1208
# dropwizard omc--nc--ncc--max 1711
# dropwizard gpt-oss-20b 0
# dropwizard gpt-oss-120b 0
# dropwizard qwen-2d5b 0
# Essentials omc 3
# Essentials nc 5
# Essentials ncc 5
# Essentials lc 28
# Essentials lcba 48
# Essentials max 75
# Essentials omc--nc 8
# Essentials omc--nc--ncc 8
# Essentials omc--nc--ncc--lcba 49
# Essentials omc--nc--ncc--max 75
# Essentials gpt-oss-20b 0
# Essentials gpt-oss-120b 0
# Essentials qwen-2d5b 0
# mybatis-plus omc 143
# mybatis-plus nc 85
# mybatis-plus ncc 168
# mybatis-plus lc 436
# mybatis-plus lcba 514
# mybatis-plus max 1219
# mybatis-plus omc--nc 218
# mybatis-plus omc--nc--ncc 296
# mybatis-plus omc--nc--ncc--lcba 593
# mybatis-plus omc--nc--ncc--max 1224
# mybatis-plus gpt-oss-20b 0
# mybatis-plus gpt-oss-120b 0
# mybatis-plus qwen-2d5b 0
# jmeter omc 301
# jmeter nc 84
# jmeter ncc 217
# jmeter lc 1011
# jmeter lcba 1446
# jmeter max 2632
# jmeter omc--nc 354
# jmeter omc--nc--ncc 405
# jmeter omc--nc--ncc--lcba 1600
# jmeter omc--nc--ncc--max 2635
# jmeter gpt-oss-20b 0
# jmeter gpt-oss-120b 0
# jmeter qwen-2d5b 0
# spring-boot omc 4349
# spring-boot nc 105
# spring-boot ncc 3789
# spring-boot lc 9509
# spring-boot lcba 10898
# spring-boot max 20882
# spring-boot omc--nc 4405
# spring-boot omc--nc--ncc 6576
# spring-boot omc--nc--ncc--lcba 13358
# spring-boot omc--nc--ncc--max 20899
# spring-boot gpt-oss-20b 0
# spring-boot gpt-oss-120b 0
# spring-boot qwen-2d5b 0
# tomcat omc 1902
# tomcat nc 85
# tomcat ncc 790
# tomcat lc 4350
# tomcat lcba 4487
# tomcat max 16002
# tomcat omc--nc 1971
# tomcat omc--nc--ncc 2493
# tomcat omc--nc--ncc--lcba 6081
# tomcat omc--nc--ncc--max 16010
# tomcat gpt-oss-20b 0
# tomcat gpt-oss-120b 0
# tomcat qwen-2d5b 0
# vert.x omc 165
# vert.x nc 309
# vert.x ncc 3175
# vert.x lc 3931
# vert.x lcba 13832
# vert.x max 61445
# vert.x omc--nc 467
# vert.x omc--nc--ncc 3283
# vert.x omc--nc--ncc--lcba 15902
# vert.x omc--nc--ncc--max 61450
# vert.x gpt-oss-20b 0
# vert.x gpt-oss-120b 0
# vert.x qwen-2d5b 0
# facebook-android-sdk omc 2
# facebook-android-sdk nc 1
# facebook-android-sdk ncc 1
# facebook-android-sdk lc 5
# facebook-android-sdk lcba 7
# facebook-android-sdk max 7
# facebook-android-sdk omc--nc 3
# facebook-android-sdk omc--nc--ncc 3
# facebook-android-sdk omc--nc--ncc--lcba 7
# facebook-android-sdk omc--nc--ncc--max 7
# facebook-android-sdk gpt-oss-20b 0
# facebook-android-sdk gpt-oss-120b 0
# facebook-android-sdk qwen-2d5b 0
# plantuml omc 163
# plantuml nc 30
# plantuml ncc 325
# plantuml lc 927
# plantuml lcba 1945
# plantuml max 3265
# plantuml omc--nc 189
# plantuml omc--nc--ncc 461
# plantuml omc--nc--ncc--lcba 2104
# plantuml omc--nc--ncc--max 3285
# plantuml gpt-oss-20b 0
# plantuml gpt-oss-120b 0
# plantuml qwen-2d5b 0
# okhttp omc 1
# okhttp nc 0
# okhttp ncc 0
# okhttp lc 1
# okhttp lcba 0
# okhttp max 1
# okhttp omc--nc 1
# okhttp omc--nc--ncc 1
# okhttp omc--nc--ncc--lcba 1
# okhttp omc--nc--ncc--max 1
# okhttp gpt-oss-20b 0
# okhttp gpt-oss-120b 0
# okhttp qwen-2d5b 0
# Signal-Server omc 222
# Signal-Server nc 100
# Signal-Server ncc 189
# Signal-Server lc 591
# Signal-Server lcba 492
# Signal-Server max 1585
# Signal-Server omc--nc 290
# Signal-Server omc--nc--ncc 355
# Signal-Server omc--nc--ncc--lcba 682
# Signal-Server omc--nc--ncc--max 1585
# Signal-Server gpt-oss-20b 0
# Signal-Server gpt-oss-120b 0
# Signal-Server qwen-2d5b 0
# baritone omc 1
# baritone nc 0
# baritone ncc 0
# baritone lc 7
# baritone lcba 17
# baritone max 55
# baritone omc--nc 1
# baritone omc--nc--ncc 1
# baritone omc--nc--ncc--lcba 18
# baritone omc--nc--ncc--max 55
# baritone gpt-oss-20b 0
# baritone gpt-oss-120b 0
# baritone qwen-2d5b 0
# Hystrix omc 110
# Hystrix nc 5
# Hystrix ncc 90
# Hystrix lc 700
# Hystrix lcba 1924
# Hystrix max 6315
# Hystrix omc--nc 114
# Hystrix omc--nc--ncc 194
# Hystrix omc--nc--ncc--lcba 1986
# Hystrix omc--nc--ncc--max 6315
# Hystrix gpt-oss-20b 0
# Hystrix gpt-oss-120b 0
# Hystrix qwen-2d5b 0
# skywalking omc 157
# skywalking nc 142
# skywalking ncc 270
# skywalking lc 545
# skywalking lcba 689
# skywalking max 1696
# skywalking omc--nc 267
# skywalking omc--nc--ncc 363
# skywalking omc--nc--ncc--lcba 840
# skywalking omc--nc--ncc--max 1698
# skywalking gpt-oss-20b 0
# skywalking gpt-oss-120b 0
# skywalking qwen-2d5b 0
# jib omc 364
# jib nc 140
# jib ncc 848
# jib lc 1277
# jib lcba 2772
# jib max 5114
# jib omc--nc 458
# jib omc--nc--ncc 994
# jib omc--nc--ncc--lcba 3130
# jib omc--nc--ncc--max 5114
# jib gpt-oss-20b 0
# jib gpt-oss-120b 0
# jib qwen-2d5b 0
# shenyu omc 625
# shenyu nc 1075
# shenyu ncc 1761
# shenyu lc 2813
# shenyu lcba 4332
# shenyu max 16294
# shenyu omc--nc 1467
# shenyu omc--nc--ncc 2002
# shenyu omc--nc--ncc--lcba 4980
# shenyu omc--nc--ncc--max 16295
# shenyu gpt-oss-20b 0
# shenyu gpt-oss-120b 0
# shenyu qwen-2d5b 0
# MPAndroidChart omc 1
# MPAndroidChart nc 2
# MPAndroidChart ncc 5
# MPAndroidChart lc 11
# MPAndroidChart lcba 46
# MPAndroidChart max 60
# MPAndroidChart omc--nc 3
# MPAndroidChart omc--nc--ncc 6
# MPAndroidChart omc--nc--ncc--lcba 46
# MPAndroidChart omc--nc--ncc--max 60
# MPAndroidChart gpt-oss-20b 0
# MPAndroidChart gpt-oss-120b 0
# MPAndroidChart qwen-2d5b 0
# shardingsphere omc 4344
# shardingsphere nc 5
# shardingsphere ncc 6173
# shardingsphere lc 7846
# shardingsphere lcba 7492
# shardingsphere max 16727
# shardingsphere omc--nc 4344
# shardingsphere omc--nc--ncc 7188
# shardingsphere omc--nc--ncc--lcba 9800
# shardingsphere omc--nc--ncc--max 16727
# shardingsphere gpt-oss-20b 0
# shardingsphere gpt-oss-120b 0
# shardingsphere qwen-2d5b 0
# seatunnel omc 690
# seatunnel nc 244
# seatunnel ncc 1099
# seatunnel lc 2008
# seatunnel lcba 2743
# seatunnel max 6608
# seatunnel omc--nc 851
# seatunnel omc--nc--ncc 1352
# seatunnel omc--nc--ncc--lcba 2995
# seatunnel omc--nc--ncc--max 6609
# seatunnel gpt-oss-20b 0
# seatunnel gpt-oss-120b 0
# seatunnel qwen-2d5b 0
# Activiti omc 281
# Activiti nc 146
# Activiti ncc 1437
# Activiti lc 3089
# Activiti lcba 8965
# Activiti max 24382
# Activiti omc--nc 413
# Activiti omc--nc--ncc 1572
# Activiti omc--nc--ncc--lcba 9836
# Activiti omc--nc--ncc--max 24383
# Activiti gpt-oss-20b 0
# Activiti gpt-oss-120b 0
# Activiti qwen-2d5b 0
# metrics omc 214
# metrics nc 4
# metrics ncc 385
# metrics lc 816
# metrics lcba 1207
# metrics max 2453
# metrics omc--nc 217
# metrics omc--nc--ncc 534
# metrics omc--nc--ncc--lcba 1403
# metrics omc--nc--ncc--max 2454
# metrics gpt-oss-20b 0
# metrics gpt-oss-120b 0
# metrics qwen-2d5b 0
# grpc-java omc 831
# grpc-java nc 159
# grpc-java ncc 1860
# grpc-java lc 4408
# grpc-java lcba 8506
# grpc-java max 27163
# grpc-java omc--nc 954
# grpc-java omc--nc--ncc 2384
# grpc-java omc--nc--ncc--lcba 9538
# grpc-java omc--nc--ncc--max 27163
# grpc-java gpt-oss-20b 0
# grpc-java gpt-oss-120b 0
# grpc-java qwen-2d5b 0
# incubator-seata omc 1735
# incubator-seata nc 1326
# incubator-seata ncc 3567
# incubator-seata lc 5207
# incubator-seata lcba 8001
# incubator-seata max 17516
# incubator-seata omc--nc 2534
# incubator-seata omc--nc--ncc 4081
# incubator-seata omc--nc--ncc--lcba 9090
# incubator-seata omc--nc--ncc--max 17516
# incubator-seata gpt-oss-20b 0
# incubator-seata gpt-oss-120b 0
# incubator-seata qwen-2d5b 0
# gson omc 383
# gson nc 46
# gson ncc 238
# gson lc 1397
# gson lcba 2068
# gson max 3833
# gson omc--nc 420
# gson omc--nc--ncc 577
# gson omc--nc--ncc--lcba 2244
# gson omc--nc--ncc--max 3834
# gson gpt-oss-20b 0
# gson gpt-oss-120b 0
# gson qwen-2d5b 0
# error-prone omc 58
# error-prone nc 15
# error-prone ncc 57
# error-prone lc 283
# error-prone lcba 225
# error-prone max 673
# error-prone omc--nc 69
# error-prone omc--nc--ncc 105
# error-prone omc--nc--ncc--lcba 255
# error-prone omc--nc--ncc--max 673
# error-prone gpt-oss-20b 0
# error-prone gpt-oss-120b 0
# error-prone qwen-2d5b 0
# zxing omc 53
# zxing nc 81
# zxing ncc 264
# zxing lc 372
# zxing lcba 1414
# zxing max 1978
# zxing omc--nc 129
# zxing omc--nc--ncc 297
# zxing omc--nc--ncc--lcba 1496
# zxing omc--nc--ncc--max 1979
# zxing gpt-oss-20b 0
# zxing gpt-oss-120b 0
# zxing qwen-2d5b 0
# sonarqube omc 3591
# sonarqube nc 463
# sonarqube ncc 5918
# sonarqube lc 15493
# sonarqube lcba 22262
# sonarqube max 66174
# sonarqube omc--nc 3926
# sonarqube omc--nc--ncc 7973
# sonarqube omc--nc--ncc--lcba 25233
# sonarqube omc--nc--ncc--max 66181
# sonarqube gpt-oss-20b 0
# sonarqube gpt-oss-120b 0
# sonarqube qwen-2d5b 0
# spring-framework omc 4624
# spring-framework nc 1336
# spring-framework ncc 7115
# spring-framework lc 17429
# spring-framework lcba 29178
# spring-framework max 67308
# spring-framework omc--nc 5738
# spring-framework omc--nc--ncc 10122
# spring-framework omc--nc--ncc--lcba 33385
# spring-framework omc--nc--ncc--max 67333
# spring-framework gpt-oss-20b 0
# spring-framework gpt-oss-120b 0
# spring-framework qwen-2d5b 0
# cucumber-jvm omc 349
# cucumber-jvm nc 42
# cucumber-jvm ncc 371
# cucumber-jvm lc 1190
# cucumber-jvm lcba 1324
# cucumber-jvm max 3471
# cucumber-jvm omc--nc 379
# cucumber-jvm omc--nc--ncc 643
# cucumber-jvm omc--nc--ncc--lcba 1548
# cucumber-jvm omc--nc--ncc--max 3473
# cucumber-jvm gpt-oss-20b 0
# cucumber-jvm gpt-oss-120b 0
# cucumber-jvm qwen-2d5b 0
# argouml omc 127
# argouml nc 140
# argouml ncc 213
# argouml lc 567
# argouml lcba 870
# argouml max 3055
# argouml omc--nc 212
# argouml omc--nc--ncc 276
# argouml omc--nc--ncc--lcba 964
# argouml omc--nc--ncc--max 3055
# argouml gpt-oss-20b 0
# argouml gpt-oss-120b 0
# argouml qwen-2d5b 0
# docx4j omc 164
# docx4j nc 3
# docx4j ncc 8
# docx4j lc 486
# docx4j lcba 176
# docx4j max 1569
# docx4j omc--nc 167
# docx4j omc--nc--ncc 172
# docx4j omc--nc--ncc--lcba 320
# docx4j omc--nc--ncc--max 1582
# docx4j gpt-oss-20b 0
# docx4j gpt-oss-120b 0
# docx4j qwen-2d5b 0
# mockito omc 540
# mockito nc 3
# mockito ncc 935
# mockito lc 2371
# mockito lcba 2194
# mockito max 9156
# mockito omc--nc 542
# mockito omc--nc--ncc 1331
# mockito omc--nc--ncc--lcba 3054
# mockito omc--nc--ncc--max 9175
# mockito gpt-oss-20b 0
# mockito gpt-oss-120b 0
# mockito qwen-2d5b 0
# async-http-client omc 53
# async-http-client nc 38
# async-http-client ncc 111
# async-http-client lc 349
# async-http-client lcba 613
# async-http-client max 1677
# async-http-client omc--nc 89
# async-http-client omc--nc--ncc 152
# async-http-client omc--nc--ncc--lcba 650
# async-http-client omc--nc--ncc--max 1677
# async-http-client gpt-oss-20b 0
# async-http-client gpt-oss-120b 0
# async-http-client qwen-2d5b 0
# commons-io omc 798
# commons-io nc 412
# commons-io ncc 1690
# commons-io lc 2452
# commons-io lcba 3573
# commons-io max 6616
# commons-io omc--nc 1113
# commons-io omc--nc--ncc 2047
# commons-io omc--nc--ncc--lcba 4368
# commons-io omc--nc--ncc--max 6619
# commons-io gpt-oss-20b 0
# commons-io gpt-oss-120b 0
# commons-io qwen-2d5b 0
# jedis omc 219
# jedis nc 2874
# jedis ncc 6917
# jedis lc 4740
# jedis lcba 8151
# jedis max 22330
# jedis omc--nc 3056
# jedis omc--nc--ncc 6993
# jedis omc--nc--ncc--lcba 11586
# jedis omc--nc--ncc--max 22332
# jedis gpt-oss-20b 0
# jedis gpt-oss-120b 0
# jedis qwen-2d5b 0
# AntennaPod omc 97
# AntennaPod nc 29
# AntennaPod ncc 135
# AntennaPod lc 346
# AntennaPod lcba 694
# AntennaPod max 2156
# AntennaPod omc--nc 121
# AntennaPod omc--nc--ncc 179
# AntennaPod omc--nc--ncc--lcba 737
# AntennaPod omc--nc--ncc--max 2156
# AntennaPod gpt-oss-20b 0
# AntennaPod gpt-oss-120b 0
# AntennaPod qwen-2d5b 0
# pmd omc 257
# pmd nc 137
# pmd ncc 343
# pmd lc 1479
# pmd lcba 2741
# pmd max 7334
# pmd omc--nc 357
# pmd omc--nc--ncc 514
# pmd omc--nc--ncc--lcba 2924
# pmd omc--nc--ncc--max 7336
# pmd gpt-oss-20b 0
# pmd gpt-oss-120b 0
# pmd qwen-2d5b 0
# hector omc 44
# hector nc 25
# hector ncc 119
# hector lc 328
# hector lcba 645
# hector max 1814
# hector omc--nc 62
# hector omc--nc--ncc 150
# hector omc--nc--ncc--lcba 704
# hector omc--nc--ncc--max 1814
# hector gpt-oss-20b 0
# hector gpt-oss-120b 0
# hector qwen-2d5b 0
# ant omc 834
# ant nc 92
# ant ncc 260
# ant lc 2358
# ant lcba 2374
# ant max 6203
# ant omc--nc 914
# ant omc--nc--ncc 1055
# ant omc--nc--ncc--lcba 3188
# ant omc--nc--ncc--max 6375
# ant gpt-oss-20b 0
# ant gpt-oss-120b 0
# ant qwen-2d5b 0
# junit5 omc 757
# junit5 nc 58
# junit5 ncc 1308
# junit5 lc 2911
# junit5 lcba 3692
# junit5 max 11743
# junit5 omc--nc 807
# junit5 omc--nc--ncc 1825
# junit5 omc--nc--ncc--lcba 4924
# junit5 omc--nc--ncc--max 11764
# junit5 gpt-oss-20b 0
# junit5 gpt-oss-120b 0
# junit5 qwen-2d5b 0
# byte-buddy omc 1017
# byte-buddy nc 243
# byte-buddy ncc 1899
# byte-buddy lc 4724
# byte-buddy lcba 6564
# byte-buddy max 24530
# byte-buddy omc--nc 1220
# byte-buddy omc--nc--ncc 2761
# byte-buddy omc--nc--ncc--lcba 8477
# byte-buddy omc--nc--ncc--max 24551
# byte-buddy gpt-oss-20b 0
# byte-buddy gpt-oss-120b 0
# byte-buddy qwen-2d5b 0
# HMCL omc 12
# HMCL nc 38
# HMCL ncc 45
# HMCL lc 179
# HMCL lcba 239
# HMCL max 560
# HMCL omc--nc 50
# HMCL omc--nc--ncc 57
# HMCL omc--nc--ncc--lcba 253
# HMCL omc--nc--ncc--max 563
# HMCL gpt-oss-20b 0
# HMCL gpt-oss-120b 0
# HMCL qwen-2d5b 0
# netty omc 528
# netty nc 421
# netty ncc 3272
# netty lc 5510
# netty lcba 16135
# netty max 55762
# netty omc--nc 872
# netty omc--nc--ncc 3585
# netty omc--nc--ncc--lcba 17952
# netty omc--nc--ncc--max 55763
# netty gpt-oss-20b 0
# netty gpt-oss-120b 0
# netty qwen-2d5b 0
# junit4 omc 355
# junit4 nc 16
# junit4 ncc 278
# junit4 lc 1203
# junit4 lcba 1521
# junit4 max 3277
# junit4 omc--nc 365
# junit4 omc--nc--ncc 585
# junit4 omc--nc--ncc--lcba 1892
# junit4 omc--nc--ncc--max 3326
# junit4 gpt-oss-20b 0
# junit4 gpt-oss-120b 0
# junit4 qwen-2d5b 0
# SmartTube omc 214
# SmartTube nc 78
# SmartTube ncc 675
# SmartTube lc 1296
# SmartTube lcba 2476
# SmartTube max 5898
# SmartTube omc--nc 287
# SmartTube omc--nc--ncc 796
# SmartTube omc--nc--ncc--lcba 2758
# SmartTube omc--nc--ncc--max 5898
# SmartTube gpt-oss-20b 0
# SmartTube gpt-oss-120b 0
# SmartTube qwen-2d5b 0
# j2objc omc 924
# j2objc nc 177
# j2objc ncc 400
# j2objc lc 2010
# j2objc lcba 1993
# j2objc max 4849
# j2objc omc--nc 1018
# j2objc omc--nc--ncc 1201
# j2objc omc--nc--ncc--lcba 2501
# j2objc omc--nc--ncc--max 4857
# j2objc gpt-oss-20b 0
# j2objc gpt-oss-120b 0
# j2objc qwen-2d5b 0
# caffeine omc 464
# caffeine nc 110
# caffeine ncc 1329
# caffeine lc 2648
# caffeine lcba 3738
# caffeine max 9889
# caffeine omc--nc 565
# caffeine omc--nc--ncc 1636
# caffeine omc--nc--ncc--lcba 4454
# caffeine omc--nc--ncc--max 9894
# caffeine gpt-oss-20b 0
# caffeine gpt-oss-120b 0
# caffeine qwen-2d5b 0
# mongo-java-driver omc 247
# mongo-java-driver nc 374
# mongo-java-driver ncc 1259
# mongo-java-driver lc 2151
# mongo-java-driver lcba 4509
# mongo-java-driver max 12497
# mongo-java-driver omc--nc 603
# mongo-java-driver omc--nc--ncc 1444
# mongo-java-driver omc--nc--ncc--lcba 5272
# mongo-java-driver omc--nc--ncc--max 12499
# mongo-java-driver gpt-oss-20b 0
# mongo-java-driver gpt-oss-120b 0
# mongo-java-driver qwen-2d5b 0
# dubbo omc 606
# dubbo nc 1338
# dubbo ncc 2309
# dubbo lc 3773
# dubbo lcba 7230
# dubbo max 17316
# dubbo omc--nc 1757
# dubbo omc--nc--ncc 2593
# dubbo omc--nc--ncc--lcba 7905
# dubbo omc--nc--ncc--max 17319
# dubbo gpt-oss-20b 0
# dubbo gpt-oss-120b 0
# dubbo qwen-2d5b 0
# voldemort omc 88
# voldemort nc 86
# voldemort ncc 258
# voldemort lc 876
# voldemort lcba 1659
# voldemort max 5187
# voldemort omc--nc 162
# voldemort omc--nc--ncc 322
# voldemort omc--nc--ncc--lcba 1760
# voldemort omc--nc--ncc--max 5190
# voldemort gpt-oss-20b 0
# voldemort gpt-oss-120b 0
# voldemort qwen-2d5b 0
# redisson omc 824
# redisson nc 552
# redisson ncc 1527
# redisson lc 2977
# redisson lcba 5024
# redisson max 11503
# redisson omc--nc 1376
# redisson omc--nc--ncc 2341
# redisson omc--nc--ncc--lcba 5612
# redisson omc--nc--ncc--max 11504
# redisson gpt-oss-20b 0
# redisson gpt-oss-120b 0
# redisson qwen-2d5b 0
# spring-cloud-alibaba omc 39
# spring-cloud-alibaba nc 16
# spring-cloud-alibaba ncc 20
# spring-cloud-alibaba lc 77
# spring-cloud-alibaba lcba 163
# spring-cloud-alibaba max 261
# spring-cloud-alibaba omc--nc 45
# spring-cloud-alibaba omc--nc--ncc 48
# spring-cloud-alibaba omc--nc--ncc--lcba 184
# spring-cloud-alibaba omc--nc--ncc--max 261
# spring-cloud-alibaba gpt-oss-20b 0
# spring-cloud-alibaba gpt-oss-120b 0
# spring-cloud-alibaba qwen-2d5b 0
# dbeaver omc 93
# dbeaver nc 8
# dbeaver ncc 112
# dbeaver lc 285
# dbeaver lcba 311
# dbeaver max 620
# dbeaver omc--nc 99
# dbeaver omc--nc--ncc 169
# dbeaver omc--nc--ncc--lcba 341
# dbeaver omc--nc--ncc--max 623
# dbeaver gpt-oss-20b 0
# dbeaver gpt-oss-120b 0
# dbeaver qwen-2d5b 0
# auto omc 252
# auto nc 35
# auto ncc 77
# auto lc 316
# auto lcba 344
# auto max 396
# auto omc--nc 283
# auto omc--nc--ncc 301
# auto omc--nc--ncc--lcba 375
# auto omc--nc--ncc--max 401
# auto gpt-oss-20b 0
# auto gpt-oss-120b 0
# auto qwen-2d5b 0
# ExoPlayer omc 833
# ExoPlayer nc 77
# ExoPlayer ncc 2693
# ExoPlayer lc 3937
# ExoPlayer lcba 6554
# ExoPlayer max 22466
# ExoPlayer omc--nc 905
# ExoPlayer omc--nc--ncc 3170
# ExoPlayer omc--nc--ncc--lcba 8066
# ExoPlayer omc--nc--ncc--max 22466
# ExoPlayer gpt-oss-20b 0
# ExoPlayer gpt-oss-120b 0
# ExoPlayer qwen-2d5b 0
# Paper omc 148
# Paper nc 79
# Paper ncc 169
# Paper lc 474
# Paper lcba 838
# Paper max 1366
# Paper omc--nc 223
# Paper omc--nc--ncc 295
# Paper omc--nc--ncc--lcba 952
# Paper omc--nc--ncc--max 1368
# Paper gpt-oss-20b 0
# Paper gpt-oss-120b 0
# Paper qwen-2d5b 0
# wiremock omc 430
# wiremock nc 11
# wiremock ncc 1176
# wiremock lc 2535
# wiremock lcba 4046
# wiremock max 15630
# wiremock omc--nc 439
# wiremock omc--nc--ncc 1515
# wiremock omc--nc--ncc--lcba 4832
# wiremock omc--nc--ncc--max 15630
# wiremock gpt-oss-20b 0
# wiremock gpt-oss-120b 0
# wiremock qwen-2d5b 0
# commons-lang omc 1482
# commons-lang nc 825
# commons-lang ncc 3488
# commons-lang lc 4423
# commons-lang lcba 5530
# commons-lang max 8856
# commons-lang omc--nc 2188
# commons-lang omc--nc--ncc 4201
# commons-lang omc--nc--ncc--lcba 6781
# commons-lang omc--nc--ncc--max 8860
# commons-lang gpt-oss-20b 0
# commons-lang gpt-oss-120b 0
# commons-lang qwen-2d5b 0
# atmosphere omc 14
# atmosphere nc 6
# atmosphere ncc 86
# atmosphere lc 259
# atmosphere lcba 304
# atmosphere max 1515
# atmosphere omc--nc 19
# atmosphere omc--nc--ncc 93
# atmosphere omc--nc--ncc--lcba 358
# atmosphere omc--nc--ncc--max 1515
# atmosphere gpt-oss-20b 0
# atmosphere gpt-oss-120b 0
# atmosphere qwen-2d5b 0
# visualvm omc 73
# visualvm nc 24
# visualvm ncc 78
# visualvm lc 173
# visualvm lcba 191
# visualvm max 431
# visualvm omc--nc 91
# visualvm omc--nc--ncc 142
# visualvm omc--nc--ncc--lcba 226
# visualvm omc--nc--ncc--max 431
# visualvm gpt-oss-20b 0
# visualvm gpt-oss-120b 0
# visualvm qwen-2d5b 0
# dagger omc 309
# dagger nc 42
# dagger ncc 200
# dagger lc 695
# dagger lcba 598
# dagger max 1454
# dagger omc--nc 321
# dagger omc--nc--ncc 441
# dagger omc--nc--ncc--lcba 776
# dagger omc--nc--ncc--max 1455
# dagger gpt-oss-20b 0
# dagger gpt-oss-120b 0
# dagger qwen-2d5b 0
# feign omc 264
# feign nc 15
# feign ncc 248
# feign lc 735
# feign lcba 707
# feign max 2164
# feign omc--nc 278
# feign omc--nc--ncc 424
# feign omc--nc--ncc--lcba 908
# feign omc--nc--ncc--max 2164
# feign gpt-oss-20b 0
# feign gpt-oss-120b 0
# feign qwen-2d5b 0
# hibernate-search omc 247
# hibernate-search nc 223
# hibernate-search ncc 1523
# hibernate-search lc 4142
# hibernate-search lcba 4296
# hibernate-search max 27151
# hibernate-search omc--nc 454
# hibernate-search omc--nc--ncc 1687
# hibernate-search omc--nc--ncc--lcba 5609
# hibernate-search omc--nc--ncc--max 27153
# hibernate-search gpt-oss-20b 0
# hibernate-search gpt-oss-120b 0
# hibernate-search qwen-2d5b 0
# guice omc 155
# guice nc 43
# guice ncc 601
# guice lc 1497
# guice lcba 2741
# guice max 7527
# guice omc--nc 197
# guice omc--nc--ncc 741
# guice omc--nc--ncc--lcba 3249
# guice omc--nc--ncc--max 7527
# guice gpt-oss-20b 0
# guice gpt-oss-120b 0
# guice qwen-2d5b 0
# jgit omc 918
# jgit nc 213
# jgit ncc 2446
# jgit lc 6095
# jgit lcba 14401
# jgit max 40102
# jgit omc--nc 1114
# jgit omc--nc--ncc 3201
# jgit omc--nc--ncc--lcba 16160
# jgit omc--nc--ncc--max 40110
# jgit gpt-oss-20b 0
# jgit gpt-oss-120b 0
# jgit qwen-2d5b 0
# rocketmq omc 445
# rocketmq nc 650
# rocketmq ncc 1792
# rocketmq lc 2926
# rocketmq lcba 6462
# rocketmq max 23702
# rocketmq omc--nc 978
# rocketmq omc--nc--ncc 1922
# rocketmq omc--nc--ncc--lcba 7065
# rocketmq omc--nc--ncc--max 23702
# rocketmq gpt-oss-20b 0
# rocketmq gpt-oss-120b 0
# rocketmq qwen-2d5b 0
# Apktool omc 35
# Apktool nc 0
# Apktool ncc 21
# Apktool lc 83
# Apktool lcba 200
# Apktool max 299
# Apktool omc--nc 35
# Apktool omc--nc--ncc 51
# Apktool omc--nc--ncc--lcba 214
# Apktool omc--nc--ncc--max 299
# Apktool gpt-oss-20b 0
# Apktool gpt-oss-120b 0
# Apktool qwen-2d5b 0

# %%
run_module("ptc.generator.t2p_link_evaluation")
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_link_evaluation.py", line 101, in <module>
#     all_pred_df, all_gt_df = (
#     ^^^^^^^^^^^^^^^^^^^^^^
# ValueError: not enough values to unpack (expected 2, got 0)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 run_module("ptc.generator.t2p_link_evaluation")
#
# File ~/dev/project/method-co-evolution/method-history-collector/src/mhc/util.py:129, in run_module(module_name, project_root, args)
#     126 if args:
#     127     command.extend(args)
# --> 129 subprocess.run(
#     130     command,
#     131     check=True,
#     132     cwd=project_root,
#     133 )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/shahidul/dev/project/method-co-evolution/.venv/bin/python', '-m', 'ptc.generator.t2p_link_evaluation']' returned non-zero exit status 1.

# %%
run_module("ptc.generator.generate_t2p_change")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/pulsar.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:15: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   change_df = pd.read_csv(change_file, keep_default_na=False, na_filter=False)
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/kafka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/pentaho-kettle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/wicket.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/Mindustry.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/cassandra.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/RxJava.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/jclouds.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/jOOQ.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/lombok.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/checkstyle.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/iceberg.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/lucene.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/hbase.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# ...
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/weka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/weka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/weka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/weka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/weka.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:15: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   change_df = pd.read_csv(change_file, keep_default_na=False, na_filter=False)
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/elasticsearch.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/hibernate-orm.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/intellij-community.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-120b/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/ncc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/gpt-oss-20b/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/qwen-2d5b/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/max/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/lcba/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--lcba/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc--max/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/nc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/generate_t2p_change.py:36: UserWarning: /Users/shahidul/dev/project/method-co-evolution/.cache/data/t2p-link/omc--nc--ncc/mage.csv does not exist
#   warnings.warn(f"{t2p_file} does not exist")

# %%
run_module("ptc.generator.generate_t2p_mwu")

# %%
run_module("ptc.generator.generate_t2p_delta")
