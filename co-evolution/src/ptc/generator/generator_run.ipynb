# %%
import subprocess
import sys
from pathlib import Path
from mhc.util import find_root

ROOT_DIR = find_root(Path.cwd())

def run_module(module_name: str):
    subprocess.run(
        [sys.executable, "-m", module_name],
        check=True,
        cwd=ROOT_DIR,
    )

# %%
# #%%
# run_module("ptc.generator.generate_fan")

# %%
# run_module("ptc.generator.generate_change")

# %%
run_module("ptc.generator.generate_m2m_tech")
# Out:
# Processing: ant
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# jenkins 1 omc 5
# jenkins 2 nc 58
# jenkins 4 ncc 80
# jenkins 16 lc 32
# jenkins 8 lcba 140
# jenkins 32 max 191
# jenkins 3 omc-nc 62
# jenkins 7 omc-nc-ncc 83
# jenkins 15 omc-nc-ncc-lcba 144
# jenkins 39 omc-nc-ncc-max 191
# gson 1 omc 24
# gson 2 nc 8
# gson 4 ncc 26
# gson 16 lc 50
# gson 8 lcba 134
# gson 32 max 173
# gson 3 omc-nc 30
# gson 7 omc-nc-ncc 48
# gson 15 omc-nc-ncc-lcba 138
# gson 39 omc-nc-ncc-max 173
# commons-io 1 omc 8
# commons-io 2 nc 1
# commons-io 4 ncc 21
# commons-io 16 lc 21
# commons-io 8 lcba 53
# commons-io 32 max 84
# commons-io 3 omc-nc 8
# commons-io 7 omc-nc-ncc 25
# commons-io 15 omc-nc-ncc-lcba 59
# commons-io 39 omc-nc-ncc-max 84
# ant 1 omc 634
# ant 2 nc 376
# ant 4 ncc 521
# ant 16 lc 1849
# ant 8 lcba 3589
# ant 32 max 7623
# ant 3 omc-nc 1000
# ant 7 omc-nc-ncc 1133
# ant 15 omc-nc-ncc-lcba 4060
# ant 39 omc-nc-ncc-max 7696
# dubbo 1 omc 8
# dubbo 2 nc 41
# dubbo 4 ncc 62
# dubbo 16 lc 41
# dubbo 8 lcba 131
# dubbo 32 max 266
# dubbo 3 omc-nc 44
# dubbo 7 omc-nc-ncc 65
# dubbo 15 omc-nc-ncc-lcba 145
# dubbo 39 omc-nc-ncc-max 266
# commons-lang 1 omc 9
# commons-lang 2 nc 37
# commons-lang 4 ncc 186
# commons-lang 16 lc 41
# commons-lang 8 lcba 290
# commons-lang 32 max 358
# commons-lang 3 omc-nc 44
# commons-lang 7 omc-nc-ncc 188
# commons-lang 15 omc-nc-ncc-lcba 312
# commons-lang 39 omc-nc-ncc-max 358
# jfreechart 1 omc 5
# jfreechart 2 nc 9
# jfreechart 4 ncc 16
# jfreechart 16 lc 26
# jfreechart 8 lcba 115
# jfreechart 32 max 133
# jfreechart 3 omc-nc 14
# jfreechart 7 omc-nc-ncc 21
# jfreechart 15 omc-nc-ncc-lcba 116
# jfreechart 39 omc-nc-ncc-max 133

# %%
run_module("ptc.generator.t2p_link_evaluation")

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.aggregate")
