# %%
import subprocess
import sys
from pathlib import Path
from mhc.util import find_root

ROOT_DIR = find_root(Path.cwd())

def run_module(module_name: str):
    subprocess.run(
        [sys.executable, "-m", module_name],
        check=True,
        cwd=ROOT_DIR,
    )

# %%
# #%%
# run_module("ptc.generator.generate_fan")

# %%
# run_module("ptc.generator.generate_change")

# %%
run_module("ptc.generator.generate_m2m_tech")
# Out:
# Processing: ant
# Processing: commons-io
# Processing: commons-lang
# Processing: dubbo
# Processing: gson
# Processing: jfreechart
# Processing: jenkins
# Finished.

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# jenkins 1 o2o 399
# jenkins 2 nc 724
# jenkins 4 ncc 1526
# jenkins 16 lc 1930
# jenkins 8 lcba 6979
# jenkins 32 max 11073
# jenkins 3 o2o-nc 1108
# jenkins 7 o2o-nc-ncc 1835
# jenkins 15 o2o-nc-ncc-lcba 7362
# jenkins 39 o2o-nc-ncc-max 11074
# gson 1 o2o 255
# gson 2 nc 33
# gson 4 ncc 238
# gson 16 lc 1040
# gson 8 lcba 2748
# gson 32 max 5239
# gson 3 o2o-nc 287
# gson 7 o2o-nc-ncc 487
# gson 15 o2o-nc-ncc-lcba 2841
# gson 39 o2o-nc-ncc-max 5239
# commons-io 1 o2o 264
# commons-io 2 nc 894
# commons-io 4 ncc 1943
# commons-io 16 lc 970
# commons-io 8 lcba 3887
# commons-io 32 max 5356
# commons-io 3 o2o-nc 1136
# commons-io 7 o2o-nc-ncc 2068
# commons-io 15 o2o-nc-ncc-lcba 4227
# commons-io 39 o2o-nc-ncc-max 5356
# ant 1 o2o 598
# ant 2 nc 380
# ant 4 ncc 601
# ant 16 lc 1886
# ant 8 lcba 4407
# ant 32 max 8343
# ant 3 o2o-nc 970
# ant 7 o2o-nc-ncc 1181
# ant 15 o2o-nc-ncc-lcba 4885
# ant 39 o2o-nc-ncc-max 8406
# dubbo 1 o2o 403
# dubbo 2 nc 2996
# dubbo 4 ncc 4442
# dubbo 16 lc 3625
# dubbo 8 lcba 14705
# dubbo 32 max 29243
# dubbo 3 o2o-nc 3243
# dubbo 7 o2o-nc-ncc 4591
# dubbo 15 o2o-nc-ncc-lcba 15540
# dubbo 39 o2o-nc-ncc-max 29245
# commons-lang 1 o2o 706
# commons-lang 2 nc 3579
# commons-lang 4 ncc 10771
# commons-lang 16 lc 2976
# commons-lang 8 lcba 19278
# commons-lang 32 max 21876
# commons-lang 3 o2o-nc 4252
# commons-lang 7 o2o-nc-ncc 10992
# commons-lang 15 o2o-nc-ncc-lcba 19956
# commons-lang 39 o2o-nc-ncc-max 21876
# jfreechart 1 o2o 399
# jfreechart 2 nc 2873
# jfreechart 4 ncc 3458
# jfreechart 16 lc 2255
# jfreechart 8 lcba 9806
# jfreechart 32 max 13976
# jfreechart 3 o2o-nc 3271
# jfreechart 7 o2o-nc-ncc 3816
# jfreechart 15 o2o-nc-ncc-lcba 10029
# jfreechart 39 o2o-nc-ncc-max 13976

# %%
run_module("ptc.generator.t2p_link_evaluation")

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.aggregate")
