# %%
import subprocess
import sys
from pathlib import Path
from mhc.util import find_root

ROOT_DIR = find_root(Path.cwd())

def run_module(module_name: str):
    subprocess.run(
        [sys.executable, "-m", module_name],
        check=True,
        cwd=ROOT_DIR,
    )

# %%
# #%%
# run_module("ptc.generator.generate_fan")

# %%
# run_module("ptc.generator.generate_change")

# %%
run_module("ptc.generator.generate_m2m_tech")

# %%
run_module("ptc.generator.generate_t2p_link")
# Out:
# gson 1 o2o 266
# gson 2 nc 0
# gson 4 ncc 4
# gson 16 lc 931
# gson 8 lcba 1002
# gson 32 max 1002
# gson 7 o2o-nc-ncc 270
# gson 15 o2o-nc-ncc-lcba 1010
# gson 39 o2o-nc-ncc-max 1010
# commons-io 1 o2o 258
# commons-io 2 nc 10
# commons-io 4 ncc 80
# commons-io 16 lc 687
# commons-io 8 lcba 816
# commons-io 32 max 816
# commons-io 7 o2o-nc-ncc 336
# commons-io 15 o2o-nc-ncc-lcba 818
# commons-io 39 o2o-nc-ncc-max 818
# ant 1 o2o 599
# ant 2 nc 5
# ant 4 ncc 30
# ant 16 lc 1785
# ant 8 lcba 1529
# ant 32 max 1529
# ant 7 o2o-nc-ncc 628
# ant 15 o2o-nc-ncc-lcba 1686
# ant 39 o2o-nc-ncc-max 1686
# dubbo 1 o2o 440
# dubbo 2 nc 424
# dubbo 4 ncc 628
# dubbo 16 lc 3338
# dubbo 8 lcba 3426
# dubbo 32 max 3426
# dubbo 7 o2o-nc-ncc 983
# dubbo 15 o2o-nc-ncc-lcba 3434
# dubbo 39 o2o-nc-ncc-max 3434
# commons-lang 1 o2o 782
# commons-lang 2 nc 18
# commons-lang 4 ncc 179
# commons-lang 16 lc 2812
# commons-lang 8 lcba 2881
# commons-lang 32 max 2881
# commons-lang 7 o2o-nc-ncc 903
# commons-lang 15 o2o-nc-ncc-lcba 2894
# commons-lang 39 o2o-nc-ncc-max 2894
# jfreechart 1 o2o 399
# jfreechart 2 nc 2
# jfreechart 4 ncc 82
# jfreechart 16 lc 2255
# jfreechart 8 lcba 2193
# jfreechart 32 max 2193
# jfreechart 7 o2o-nc-ncc 470
# jfreechart 15 o2o-nc-ncc-lcba 2200
# jfreechart 39 o2o-nc-ncc-max 2200

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.t2p_link_evaluation")
# Out:
# /Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/generator/t2p_link_evaluation.py:102: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(items, ignore_index=True)

# %%
run_module("ptc.generator.aggregate")
