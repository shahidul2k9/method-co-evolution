# %%
import subprocess
import sys
from pathlib import Path
from mhc.util import find_root

ROOT_DIR = find_root(Path.cwd())

def run_module(module_name: str):
    subprocess.run(
        [sys.executable, "-m", module_name],
        check=True,
        cwd=ROOT_DIR,
    )

# %%
# #%%
# run_module("ptc.generator.generate_fan")

# %%
# run_module("ptc.generator.generate_change")

# %%
run_module("ptc.generator.generate_m2m_tech")

# %%
run_module("ptc.generator.generate_t2p_link")

# %%
run_module("ptc.generator.t2p_link_evaluation")

# %%
run_module("ptc.generator.generate_t2p_change")

# %%
run_module("ptc.generator.aggregate")

# %%
run_module("ptc.plot.fan_cdf")

# %%
run_module("ptc.plot.change_cdf")

# %%
run_module("ptc.plot.pt_change_scatter")
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/shahidul/dev/project/method-co-evolution/co-evolution/src/ptc/plot/pt_change_scatter.py", line 17, in <module>
#     for link_strategy in sorted(map(lambda entry: entry.name , filter(lambda entry: entry.is_dir(), os.scandir(f"{DATA_DIRECTORY}/t2p-change/{tool}")))):
#                                                                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# NotADirectoryError: [Errno 20] Not a directory: '/Users/shahidul/dev/project/method-co-evolution/.white/data/t2p-change/.DS_Store'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 run_module("ptc.plot.pt_change_scatter")
#
# Cell In[2], line 9, in run_module(module_name)
#       8 def run_module(module_name: str):
# ----> 9     subprocess.run(
#      10         [sys.executable, "-m", module_name],
#      11         check=True,
#      12         cwd=ROOT_DIR,
#      13     )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/shahidul/dev/project/method-co-evolution/.venv/bin/python', '-m', 'ptc.plot.pt_change_scatter']' returned non-zero exit status 1.
